# %%
import numpy as np
import matplotlib.pyplot as plt


# 피클

# %%
a = np.arange(24).reshape(2, 4, 1, 3)
# 1
a[:, 0]

a[0, :, :1, 0]

a[1, 1, 0]

a[:, 1:, 0, 2]
# Out:
# array([[ 5,  8, 11],
#        [17, 20, 23]])
