# %% [markdown]
# ## [ Numpy - ndarray 원소 접근 ] <hr>
#
# - 인덱싱 기반: 왼-> 오, 오-> 왼 2개 종류 인덱스
# - 슬라이싱: 연속적이거나 일정한 규칙이 있는 원소 접근 방식

# %%
# 모듈 로딩
# ========================
import numpy as np

# %%
# 실습 데이터 생성
