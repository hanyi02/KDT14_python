# %% [markdown]
# ### [실습] <hr>
# - 'U'/'u'/'+': 이미지 크게
# - 'D'/'d'/'-': 이미지 작게
# - 'X'/'x': 모든 창 닫기

# %%
import cv2
import os
import matplotlib.pyplot as plt
import koreanize_matplotlib
import numpy as np
import matplotlib.cm as cm

# %%
IMAGE_FILE='../Day02/img2.png'

img=cv2.imread(IMAGE_FILE)
img=cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

plt.imshow(img)
plt.show()

# %%
if img is None:
    print('이미지를 불러오지 못했습니다.')

else:
    cv2.imshow("bugi", img)

    key = cv2.waitKey(0) & 0xFF

    if key in [ord('U'), ord('u'), ord('+')]:
        img=cv2.resize(img, (500, 500))

    elif key in [ord('D'), ord('d'), ord('-')]:
        img=cv2.resize(img, (50, 50))

    elif key in [ord('X'), ord('x')]:
        print('종료합니다.')

    cv2.destroyAllWindows()

# %%
import cv2

img = cv2.imread('./img2.png')

if img is None:
    print('이미지를 불러오지 못했습니다.')

else:
    while True:
        cv2.imshow("bugi", img)

        key = cv2.waitKey(0) & 0xFF

        h, w = img.shape[:2]

        if key in [ord('U'), ord('u'), ord('+')]:
            img = cv2.resize(img, (int(w * 1.2), int(h * 1.2)))
            print('이미지 확대')

        elif key in [ord('D'), ord('d'), ord('-')]:
            img = cv2.resize(img, (int(w * 0.8), int(h * 0.8)))
            print('이미지 축소')

        elif key in [ord('X'), ord('x')]:
            print('종료합니다.')
            break

    cv2.destroyAllWindows()
# Out:
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 축소
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 이미지 확대
# 종료합니다.
