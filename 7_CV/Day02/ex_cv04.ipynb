# %% [markdown]
# ### [ 이미지 데이터 채널 분리 & 병합 ]  <hr>
#
# - 채널 분리: cv2.split()
#     * openCV는 BGR 순서 채널=> 분리 시 BGR 순서로 채널 추출됨
# - 채널 병합: cv2.merge((채널, 채널, 채널))

# %%
import cv2
import os
import matplotlib.pyplot as plt
import koreanize_matplotlib
import numpy as np
import matplotlib.cm as cm

# %%
## 데이터 준비

FILE_PATH= '../Images/girl.jpg'

# %%
# 이미지 데이터 로딩
imgNP= cv2.imread(FILE_PATH)

print(f'shape: {imgNP.shape}, nDim: {imgNP.ndim}D')
# Out:
# shape: (293, 406, 3), nDim: 3D

# %%
# openCV& matplotlib
# openCV로 이미지 로딩 시 채널 순서가 BGR
# 일반적인 이미지 SW/Package는 채널 순서 RGB
# 다른 곳에 사용 시 채널 순서 변경 필수!

plt.imshow(imgNP)
plt.show()


# cv2.imshow("girl", imgNP)
# cv2.waitKey()
# cv2.destroyWindow("girl")


img1 = cv2.cvtColor(imgNP, cv2.COLOR_RGB2BGR)
plt.imshow(img1)
plt.show()

# %%
# ===================================
# 채널 분리: cv2. split()
# ====================================
b_channel, g_channel, r_channel= cv2.split(imgNP)

print(f'b_channel=> {b_channel.shape}, {b_channel.dtype}')
print(f'g_channel=> {g_channel.shape}, {g_channel.dtype}')
print(f'r_channel=> {r_channel.shape}, {r_channel.dtype}')

# b_channel= cv2.cvtColor(b_channel, cv2.COLOR_RGB2BGR)
# g_channel= cv2.cvtColor(g_channel, cv2.COLOR_RGB2BGR)
# r_channel= cv2.cvtColor(r_channel, cv2.COLOR_RGB2BGR)



fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].imshow(b_channel)
axes[0].set_title('b_channel')
axes[0].axis('off')

axes[1].imshow(g_channel)
axes[1].set_title('g_channel')
axes[1].axis('off')

axes[2].imshow(r_channel)
axes[2].set_title('r_channel')
axes[2].axis('off')

plt.tight_layout()
plt.show()
# Out:
# b_channel=> (293, 406), uint8
# g_channel=> (293, 406), uint8
# r_channel=> (293, 406), uint8

# %%
b_channel= cv2.cvtColor(b_channel, cv2.COLOR_RGB2BGR)
g_channel= cv2.cvtColor(g_channel, cv2.COLOR_RGB2BGR)
r_channel= cv2.cvtColor(r_channel, cv2.COLOR_RGB2BGR)



fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].imshow(b_channel)
axes[0].set_title('b_channel')
axes[0].axis('off')

axes[1].imshow(g_channel)
axes[1].set_title('g_channel')
axes[1].axis('off')

axes[2].imshow(r_channel)
axes[2].set_title('r_channel')
axes[2].axis('off')

plt.tight_layout()
plt.show()

# %%
# b_channel= cv2.cvtColor(b_channel, cv2.COLOR_RGB2BGR)
# g_channel= cv2.cvtColor(g_channel, cv2.COLOR_RGB2BGR)
# r_channel= cv2.cvtColor(r_channel, cv2.COLOR_RGB2BGR)


fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].imshow(b_channel, cmap=cm.gray)
axes[0].set_title('b_channel')
axes[0].axis('off')

axes[1].imshow(g_channel, cmap=cm.gray)
axes[1].set_title('g_channel')
axes[1].axis('off')

axes[2].imshow(r_channel, cmap=cm.gray)
axes[2].set_title('r_channel')
axes[2].axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 채널 분리
b_channel, g_channel, r_channel = cv2.split(imgNP)

zeros = np.zeros_like(b_channel)

# matplotlib은 RGB 순서로 보여줌
b_img = cv2.merge([zeros, zeros, b_channel])  # 파랑만 보이게
g_img = cv2.merge([zeros, g_channel, zeros])  # 초록만 보이게
r_img = cv2.merge([r_channel, zeros, zeros])  # 빨강만 보이게

# 원본 컬러 이미지로 다시 합치기
# OpenCV 기준: BGR
total_bgr = cv2.merge([b_channel, g_channel, r_channel])

# matplotlib 출력용 RGB 변환
total_rgb = cv2.cvtColor(total_bgr, cv2.COLOR_BGR2RGB)

fig, axes = plt.subplots(1, 4, figsize=(16, 4))

axes[0].imshow(b_img)
axes[0].set_title('B channel color')
axes[0].axis('off')

axes[1].imshow(g_img)
axes[1].set_title('G channel color')
axes[1].axis('off')

axes[2].imshow(r_img)
axes[2].set_title('R channel color')
axes[2].axis('off')

axes[3].imshow(total_rgb)
axes[3].set_title('Total color')
axes[3].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 3)
title=['b_channel', 'g_channel', 'r_channel']
datas= [b_channel, g_channel, r_channel]

for ax, title, data in zip(ax, title, datas):
    ax.set_title(title)
    ax.imshow(data, cmap=cm.gray)
plt.show()

# %%
rgbNP= cv2.merge((r_channel, g_channel, b_channel))

titles=['imgNP', 'rgbNP']
datas=[imgNP, rgbNP]

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

for ax, title, data in zip(axes, titles, datas):
    ax.set_title(title)
    ax.imshow(datas)
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 10
#       6 fig, axes = plt.subplots(1, 2, figsize=(10, 4))
#       7
#       8 for ax, title, data in zip(axes, titles, datas):
#       9     ax.set_title(title)
# ---> 10     ax.imshow(datas)
#      11     ax.axis('off')
#      12
#      13 plt.tight_layout()
#
# File c:\Users\KDT30\anaconda3\envs\hanicv\Lib\site-packages\matplotlib\__init__.py:1476, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1473 @functools.wraps(func)
#    1474 def inner(ax, *args, data=None, **kwargs):
#    1475     if data is None:
# -> 1476         return func(
#    1477             ax,
#    1478             *map(sanitize_sequence, args),
#    1479             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1481     bound = new_sig.bind(ax, *args, **kwargs)
# ...
